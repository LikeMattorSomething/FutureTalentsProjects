# %% [markdown]
# <a href="https://colab.research.google.com/github/LikeMattorSomething/FutureTalentsProjects/blob/main/grace_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize


GraceData = pd.read_csv("/content/drive/MyDrive/Future Talents Data/Grace_All years combined 08-07-2025.csv")

#GraceData.boxplot(column=["Glucose","HbA1C"])
#plt.show()

#GraceData["Glucose"]=(GraceData["Glucose"]-GraceData["Glucose"].min())/(GraceData["Glucose"].max()-GraceData["Glucose"].min())
#GraceData["HbA1C"]=(GraceData["HbA1C"]-GraceData["HbA1C"].min())/(GraceData["HbA1C"].max()-GraceData["HbA1C"].min())

#GraceData.keys()
#GraceData.info()

#GraceData.boxplot(column=["Glucose","HbA1C"])
#plt.show()


freq = GraceData["GenHelf"].value_counts().sort_index()
display(GraceData["GenHelf"].value_counts())
freq.plot.bar(title="General Health")
# Out:
# GenHelf
#  2    3541
#  1    2810
#  3    1545
#  4     351
#  5      96
# -8       4
# Name: count, dtype: int64
# <Axes: title={'center': 'General Health'}, xlabel='GenHelf'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


GraceData = pd.read_csv("/content/drive/MyDrive/Future Talents Data/Grace_All years combined 08-07-2025.csv")

GraceData["Diabetes"].fillna(value=0)

for Column_Name in GraceData.columns:

  if Column_Name != 'seriali': # Exclude 'seriali' column from plotting

    print("Feature: ",Column_Name)
    print("Datatype: ",GraceData[Column_Name].dtype)

    if GraceData[Column_Name].dtype == int or GraceData[Column_Name].dtype == float:


        if GraceData[Column_Name].nunique() < 5:

          GraceData[Column_Name].value_counts().plot(kind='pie',autopct='%1.0f%%',title=Column_Name)
          display(GraceData[Column_Name].value_counts())

          plt.show()

        else:
          GraceData.plot.hist(y=Column_Name,bins=range(int(GraceData[Column_Name].max()+1)),title=Column_Name)

          plt.show()


    elif Column_Name == "Diabetes":
        TempDiabetesData = (GraceData[Column_Name].replace("#NULL!","No Data"))
        TempDiabetesData = TempDiabetesData.astype(str)
        TempDiabetesData.value_counts().plot(kind='pie',autopct='%1.0f%%',title=Column_Name)

        plt.show()

        display(TempDiabetesData.value_counts())

    else:
        GraceData[Column_Name].value_counts().plot(kind='pie',autopct='%1.0f%%',title=Column_Name)

        plt.show()

        if GraceData[Column_Name].nunique() < 5:
          display(GraceData[Column_Name].value_counts())
# Out:
# Feature:  SurveyYear
# Datatype:  int64
# Feature:  Ndays
# Datatype:  int64
# Ndays
# 4    8166
# 3     181
# Name: count, dtype: int64
# Feature:  Diabetes
# Datatype:  object
# Diabetes
# 1          4209
# -1         3301
# No Data     586
# 2           251
# Name: count, dtype: int64
# Feature:  Age
# Datatype:  int64
# Feature:  Sex
# Datatype:  int64
# Sex
# 2    4880
# 1    3467
# Name: count, dtype: int64
# Feature:  BMI
# Datatype:  int64
# Feature:  Waist
# Datatype:  int64
# Feature:  ethgr5
# Datatype:  int64
# Feature:  ethgr2
# Datatype:  float64
# ethgr2
#  1.0    7707
#  2.0     629
# -1.0      11
# Name: count, dtype: int64
# Feature:  Country
# Datatype:  object
# Feature:  Glucose
# Datatype:  float64
# Feature:  HbA1C
# Datatype:  float64
# Feature:  GenHelf
# Datatype:  int64
# Feature:  Energykcal
# Datatype:  float64
# Feature:  FoodEkcal
# Datatype:  float64
# Feature:  Proteing
# Datatype:  float64
# Feature:  Fatg
# Datatype:  float64
# ...
